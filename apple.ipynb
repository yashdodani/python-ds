# %% [markdown]
# # Apple Revenue

# %%
import requests
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import pandas as pd
import statistics

# %%
# stock_data = pd.read_csv("AppleStockPrices.csv")
revenue_data = pd.read_csv("AppleRevenue.csv")
stock_year = revenue_data["Year"]
total_revenue = revenue_data["Total Revenue"]

plt.plot(stock_year , total_revenue)
plt.title("Apple Revenue growth over years")
plt.xlabel("Year")
plt.ylabel("Revenue in millions")
# Out:
# Text(0, 0.5, 'Revenue in millions')
