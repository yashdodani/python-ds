# %%
import matplotlib.pyplot as plt

# %%
blood_sugar = [113, 85, 90 , 150, 149]

# %%
plt.hist(blood_sugar, bins=3, rwidth=0.95)
# Out:
# (array([2., 1., 2.]),
#  array([ 85.        , 106.66666667, 128.33333333, 150.        ]),
#  <BarContainer object of 3 artists>)
